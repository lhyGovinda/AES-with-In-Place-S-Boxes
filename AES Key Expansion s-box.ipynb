# %% [markdown]
# The verification circuit comprises 28 qubits (including input registers q1-q2, output registers q5-q6 and auxiliary registers q3-q4,q7) and 28 classical bits.

# %%
import numpy as np
from qiskit import *
from qiskit_aer import Aer
q1=QuantumRegister(4,'i_1')
q2=QuantumRegister(4,'i_2')
q3=QuantumRegister(4,'a_1')
q4=QuantumRegister(4,'a_2')
q5=QuantumRegister(4,'o_1')
q6=QuantumRegister(4,'o_2')
q7=QuantumRegister(4,'a_3')

c1 = ClassicalRegister(4)
c2 = ClassicalRegister(4)
c3 = ClassicalRegister(4)
c4 = ClassicalRegister(4)
c5 = ClassicalRegister(4)
c6 = ClassicalRegister(4)
c7 = ClassicalRegister(4)

# %% [markdown]
# Circuits of linear layers $\Phi$, $\Phi^\dagger$, $(B\Phi^{-1})^\dagger$ and $B\Phi^{-1}()\oplus c$ :

# %%
qc=QuantumCircuit(q1,q2)
def Phi(q1,q2):
        qc.cx(q1[2],q1[0])
        qc.cx(q2[1],q1[1])
        qc.cx(q2[3],q1[1])
        qc.cx(q1[1],q2[2])
        qc.cx(q2[2],q1[2])
        qc.cx(q1[0],q1[1])
        qc.cx(q1[3],q2[2])
        qc.cx(q2[2],q2[3])
        qc.cx(q2[2],q2[1])
        qc.cx(q2[1],q2[0])

        qc.swap(q1[3],q2[2])
        qc.swap(q1[3],q1[1])
        qc.swap(q1[3],q1[0])
        qc.swap(q1[3],q2[0])
        qc.swap(q1[3],q1[2])
        qc.swap(q1[3],q2[1])
        qc.swap(q1[3],q2[3])

def Phi_dagger(q1,q2):
    qc.swap(q1[3],q2[3])
    qc.swap(q1[3],q2[1])
    qc.swap(q1[3],q1[2])
    qc.swap(q1[3],q2[0])
    qc.swap(q1[3],q1[0])
    qc.swap(q1[3],q1[1])
    qc.swap(q1[3],q2[2])

    qc.cx(q2[1],q2[0]) 
    qc.cx(q2[2],q2[1])
    qc.cx(q2[2],q2[3])
    qc.cx(q1[3],q2[2])  
    qc.cx(q1[0],q1[1])
    qc.cx(q2[2],q1[2])
    qc.cx(q1[1],q2[2])
    qc.cx(q2[3],q1[1])
    qc.cx(q2[1],q1[1])
    qc.cx(q1[2],q1[0])
               

def B_Phi_c(q1,q2):
        qc.cx(q2[2],q1[0])
        qc.cx(q1[0],q1[2])
        qc.cx(q1[2],q1[3])
        qc.cx(q2[3],q1[0])
        qc.cx(q1[1],q1[0])
        qc.cx(q2[0],q2[3])
        qc.cx(q2[1],q2[0])
        qc.cx(q2[0],q1[1])
        qc.cx(q2[3],q2[2])
        qc.cx(q2[2],q2[1])
        qc.cx(q1[3],q2[1])
        qc.cx(q1[1],q1[2])
        qc.cx(q2[1],q2[3])
        qc.cx(q2[3],q1[1])

        qc.swap(q1[3],q2[0])
        qc.swap(q1[3],q1[1])
        qc.swap(q1[3],q2[3])
        qc.swap(q1[3],q1[0])
        qc.swap(q1[2],q2[2])

        qc.x(q2[2])
        qc.x(q2[1])
        qc.x(q1[1])
        qc.x(q1[0])

def B_Phi_inv_dagger(q1,q2):
    qc.swap(q1[2],q2[2])
    qc.swap(q1[3],q1[0])
    qc.swap(q1[3],q2[3])
    qc.swap(q1[3],q1[1])
    qc.swap(q1[3],q2[0])

    qc.cx(q2[3],q1[1])   
    qc.cx(q2[1],q2[3])
    qc.cx(q1[1],q1[2])
    qc.cx(q1[3],q2[1])
    qc.cx(q2[2],q2[1])
    qc.cx(q2[3],q2[2])
    qc.cx(q2[0],q1[1])
    qc.cx(q2[1],q2[0])
    qc.cx(q2[0],q2[3])
    qc.cx(q1[1],q1[0])
    qc.cx(q2[3],q1[0])
    qc.cx(q1[2],q1[3])   
    qc.cx(q1[0],q1[2])    
    qc.cx(q2[2],q1[0])

# %% [markdown]
# Circuits for $\theta$ and $\theta^\dagger$ :

# %%
qc=QuantumCircuit(q1,q2,q3,q4,q5,q6)
def theta(q1,q2,q3,q4):
    qc.cx(q1[3],q4[0])
    qc.cx(q2[3],q4[1])

    qc.cx(q1[2],q1[3])
    qc.cx(q1[2],q1[0])
    qc.cx(q2[2],q2[3])
    qc.cx(q2[2],q2[0])

    qc.barrier(q1,q2,q3,q4,q5,q6)

    qc.ccx(q1[0],q2[0],q3[2])
    qc.ccx(q1[1],q2[1],q3[3])
    qc.ccx(q1[2],q2[2],q3[0])
    qc.ccx(q1[3],q2[3],q3[1])
    qc.ccx(q4[0],q4[1],q4[2])

    qc.barrier(q1,q2,q3,q4,q5,q6)

    qc.cx(q1[2],q1[0])
    qc.cx(q1[2],q1[3])
    qc.cx(q2[2],q2[0])
    qc.cx(q2[2],q2[3])
    qc.cx(q3[0],q3[2])
    qc.cx(q3[1],q3[2])
    qc.cx(q3[3],q3[0])
    qc.cx(q3[2],q3[3])
    qc.cx(q3[0],q3[2])

    qc.cx(q4[2],q3[0])

    qc.cx(q1[3],q1[2])
    qc.cx(q1[1],q1[3])
    qc.cx(q1[0],q1[1])
    qc.cx(q1[1],q1[2])
    qc.cx(q2[3],q2[2])
    qc.cx(q2[1],q2[3])
    qc.cx(q2[0],q2[1])
    qc.cx(q2[1],q2[2])
    qc.cx(q3[1],q3[3])
    qc.cx(q3[0],q3[1])
    qc.cx(q3[2],q3[0])

    qc.barrier(q1,q2,q3,q4,q5,q6)

    qc.ccx(q1[0],q2[0],q3[2])
    qc.ccx(q1[1],q2[1],q3[1])
    qc.ccx(q1[2],q2[2],q3[3])
    qc.ccx(q1[3],q2[3],q3[0])
    qc.ccx(q4[0],q4[1],q4[2])

    qc.barrier(q1,q2,q3,q4,q5,q6)

    qc.cx(q1[1],q1[2])
    qc.cx(q1[0],q1[1])
    qc.cx(q1[1],q1[3])
    qc.cx(q1[3],q1[2])
    qc.cx(q2[1],q2[2])
    qc.cx(q2[0],q2[1])
    qc.cx(q2[1],q2[3])
    qc.cx(q2[3],q2[2])
    qc.cx(q3[2],q3[0])
    qc.cx(q3[0],q3[1])
    qc.cx(q3[1],q3[3])

    qc.cx(q1[3],q4[0])
    qc.cx(q2[3],q4[1])


    qc.cx(q1[0],q2[0])
    qc.cx(q1[1],q2[1])
    qc.cx(q1[2],q2[2])
    qc.cx(q1[3],q2[3])
    qc.cx(q2[3],q2[2])
    qc.cx(q2[0],q2[3])
    qc.cx(q2[2],q2[1])
    qc.cx(q2[1],q2[0])
    qc.swap(q2[1],q2[0])
    qc.swap(q2[1],q2[2])
    qc.cx(q2[0],q3[0])
    qc.cx(q2[1],q3[1])
    qc.cx(q2[2],q3[2])
    qc.cx(q2[3],q3[3])
    qc.swap(q2[1],q2[2])
    qc.swap(q2[1],q2[0])
    qc.cx(q2[1],q2[0])
    qc.cx(q2[2],q2[1])
    qc.cx(q2[0],q2[3])
    qc.cx(q2[3],q2[2])
    qc.cx(q1[0],q2[0])
    qc.cx(q1[1],q2[1])
    qc.cx(q1[2],q2[2])
    qc.cx(q1[3],q2[3])

def theta_dagger(q1,q2,q3,q4):
    qc.cx(q1[0],q2[0])
    qc.cx(q1[1],q2[1])
    qc.cx(q1[2],q2[2])
    qc.cx(q1[3],q2[3])
    qc.cx(q2[3],q2[2])
    qc.cx(q2[0],q2[3])
    qc.cx(q2[2],q2[1])
    qc.cx(q2[1],q2[0])
    qc.swap(q2[1],q2[0])
    qc.swap(q2[1],q2[2])
    qc.cx(q2[0],q3[0])
    qc.cx(q2[1],q3[1])
    qc.cx(q2[2],q3[2])
    qc.cx(q2[3],q3[3])
    qc.swap(q2[1],q2[2])
    qc.swap(q2[1],q2[0])
    qc.cx(q2[1],q2[0])
    qc.cx(q2[2],q2[1])
    qc.cx(q2[0],q2[3])
    qc.cx(q2[3],q2[2])
    qc.cx(q1[0],q2[0])
    qc.cx(q1[1],q2[1])
    qc.cx(q1[2],q2[2])
    qc.cx(q1[3],q2[3])

    qc.cx(q1[3],q4[0])
    qc.cx(q2[3],q4[1])

    qc.cx(q3[1],q3[3])
    qc.cx(q3[0],q3[1])
    qc.cx(q3[2],q3[0])
    qc.cx(q2[3],q2[2])
    qc.cx(q2[1],q2[3])
    qc.cx(q2[0],q2[1])
    qc.cx(q2[1],q2[2])
    qc.cx(q1[3],q1[2])
    qc.cx(q1[1],q1[3])
    qc.cx(q1[0],q1[1])
    qc.cx(q1[1],q1[2])

    qc.barrier(q1,q2,q3,q4,q5,q6)

    qc.ccx(q1[0],q2[0],q3[2])
    qc.ccx(q1[1],q2[1],q3[1])
    qc.ccx(q1[2],q2[2],q3[3])
    qc.ccx(q1[3],q2[3],q3[0])
    qc.ccx(q4[0],q4[1],q4[2])

    qc.barrier(q1,q2,q3,q4,q5,q6)

    qc.cx(q2[1],q2[2])
    qc.cx(q2[0],q2[1])
    qc.cx(q2[1],q2[3])
    qc.cx(q2[3],q2[2])
    qc.cx(q1[1],q1[2])
    qc.cx(q1[0],q1[1])
    qc.cx(q1[1],q1[3])
    qc.cx(q1[3],q1[2])
    qc.cx(q3[2],q3[0])
    qc.cx(q3[0],q3[1])
    qc.cx(q3[1],q3[3])

    qc.cx(q4[2],q3[0])

    qc.cx(q3[0],q3[2])
    qc.cx(q3[2],q3[3])
    qc.cx(q3[3],q3[0])
    qc.cx(q3[1],q3[2])
    qc.cx(q3[0],q3[2])
    qc.cx(q2[2],q2[3])
    qc.cx(q2[2],q2[0])
    qc.cx(q1[2],q1[3])
    qc.cx(q1[2],q1[0])

    qc.barrier(q1,q2,q3,q4,q5,q6)

    qc.ccx(q1[0],q2[0],q3[2])
    qc.ccx(q1[1],q2[1],q3[3])
    qc.ccx(q1[2],q2[2],q3[0])
    qc.ccx(q1[3],q2[3],q3[1])
    qc.ccx(q4[0],q4[1],q4[2])

    qc.barrier(q1,q2,q3,q4,q5,q6)

    qc.cx(q2[2],q2[0])
    qc.cx(q2[2],q2[3])
    qc.cx(q1[2],q1[0])
    qc.cx(q1[2],q1[3])

    qc.cx(q1[3],q4[0])
    qc.cx(q2[3],q4[1])

# %% [markdown]
# circuits for $inv_2$ and $inv_2^\dagger$ :

# %%
def inv_2(q1,q2,q3):
    qc.swap(q1[1],q1[3])
    qc.swap(q1[0],q1[1])
    qc.cx(q1[1],q1[0])
    qc.cx(q1[2],q1[0])
    qc.cx(q1[0],q1[3])
    qc.cx(q1[3],q1[2])

    qc.cx(q1[0],q2[0])
    qc.cx(q1[1],q2[1])
    qc.cx(q1[2],q2[2])
    qc.cx(q1[3],q2[3])
    qc.barrier(q1,q2,q3)
    qc.ccx(q1[3],q2[1],q3[0])
    qc.ccx(q1[2],q2[0],q3[1])
    qc.ccx(q1[1],q2[2],q3[2])
    qc.ccx(q1[0],q2[3],q3[3])
    qc.barrier(q1,q2,q3)
    qc.cx(q1[0],q2[0])
    qc.cx(q1[1],q2[1])
    qc.cx(q1[2],q2[2])
    qc.cx(q1[3],q2[3])
    qc.barrier(q1,q2,q3)
    qc.ccx(q1[3],q3[2],q2[0])
    qc.ccx(q1[2],q3[3],q2[1])
    qc.ccx(q1[0],q3[0],q2[2])
    qc.ccx(q1[1],q3[1],q2[3])
    qc.barrier(q1,q2,q3)
    qc.cx(q1[2],q2[0])
    qc.cx(q3[0],q2[1])
    qc.cx(q3[1],q3[2])
    qc.cx(q1[0],q2[2])
    qc.cx(q3[0],q2[3])
    qc.cx(q3[1],q3[3])
    qc.cx(q3[2],q2[0])
    qc.cx(q1[3],q2[1])
    qc.cx(q3[3],q2[2])
    qc.cx(q1[3],q2[0])
    qc.cx(q3[2],q2[1])
    qc.cx(q1[1],q2[2])
    qc.cx(q3[3],q2[3])
    qc.cx(q1[1],q2[3])
    qc.cx(q3[1],q3[3])
    qc.cx(q3[1],q3[2])
    qc.barrier(q1,q2,q3)
    qc.ccx(q1[0],q1[3],q3[3])
    qc.ccx(q1[1],q1[2],q3[2])
    qc.barrier(q1,q2,q3)
    qc.ccx(q1[0],q1[2],q3[1])
    qc.ccx(q1[1],q1[3],q3[0])
    qc.barrier(q1,q2,q3)

    qc.cx(q1[3],q1[2])
    qc.cx(q1[0],q1[3])
    qc.cx(q1[2],q1[0])
    qc.cx(q1[1],q1[0])
    qc.swap(q1[0],q1[1])
    qc.swap(q1[1],q1[3])

    qc.cx(q2[3],q2[2])
    qc.cx(q2[0],q2[3])
    qc.cx(q2[2],q2[0])
    qc.cx(q2[1],q2[0])
    qc.swap(q2[0],q2[1])
    qc.swap(q2[1],q2[3])

def inv_2_dagger(q1,q2,q3):
    qc.swap(q2[1], q2[3])
    qc.swap(q2[0], q2[1])
    qc.cx(q2[1], q2[0])
    qc.cx(q2[2], q2[0])
    qc.cx(q2[0], q2[3])
    qc.cx(q2[3], q2[2])

    qc.swap(q1[1], q1[3])
    qc.swap(q1[0], q1[1])
    qc.cx(q1[1], q1[0])
    qc.cx(q1[2], q1[0])
    qc.cx(q1[0], q1[3])
    qc.cx(q1[3], q1[2])

    qc.barrier(q1,q2,q3)
    qc.ccx(q1[1],q1[3],q3[0])
    qc.ccx(q1[0],q1[2],q3[1])
    qc.barrier(q1,q2,q3)
    qc.ccx(q1[1],q1[2],q3[2])
    qc.ccx(q1[0],q1[3],q3[3])
    qc.barrier(q1,q2,q3)
    qc.cx(q3[1],q3[2])
    qc.cx(q3[1],q3[3])
    qc.cx(q1[1],q2[3])
    qc.cx(q3[3],q2[3])
    qc.cx(q1[1],q2[2])
    qc.cx(q3[2],q2[1])
    qc.cx(q1[3],q2[0])
    qc.cx(q3[3],q2[2])
    qc.cx(q1[3],q2[1])
    qc.cx(q3[2],q2[0])
    qc.cx(q3[1],q3[3])
    qc.cx(q3[0],q2[3])
    qc.cx(q1[0],q2[2])
    qc.cx(q3[1],q3[2])
    qc.cx(q3[0],q2[1])
    qc.cx(q1[2],q2[0])
    qc.barrier(q1,q2,q3)
    qc.ccx(q1[1],q3[1],q2[3])
    qc.ccx(q1[0],q3[0],q2[2])
    qc.ccx(q1[2],q3[3],q2[1])
    qc.ccx(q1[3],q3[2],q2[0])
    qc.barrier(q1,q2,q3)
    qc.cx(q1[3],q2[3])
    qc.cx(q1[2],q2[2])
    qc.cx(q1[1],q2[1])
    qc.cx(q1[0],q2[0])
    qc.barrier(q1,q2,q3)
    qc.ccx(q1[0],q2[3],q3[3])
    qc.ccx(q1[1],q2[2],q3[2])
    qc.ccx(q1[2],q2[0],q3[1])
    qc.ccx(q1[3],q2[1],q3[0])
    qc.barrier(q1,q2,q3)
    qc.cx(q1[3],q2[3])
    qc.cx(q1[2],q2[2])
    qc.cx(q1[1],q2[1])
    qc.cx(q1[0],q2[0])

    qc.cx(q1[3],q1[2])
    qc.cx(q1[0],q1[3])
    qc.cx(q1[2],q1[0])
    qc.cx(q1[1],q1[0])
    qc.swap(q1[0],q1[1])
    qc.swap(q1[1],q1[3])

# %% [markdown]
# circuit for $\mathfrak{C}^*$-$mul$ :

# %%
def C_mul(q1,q2,q3,q4):
    qc.cx(q1[3],q4[0])
    qc.cx(q2[3],q4[1])

    qc.cx(q3[0],q3[2])
    qc.cx(q3[2],q3[3])
    qc.cx(q3[3],q3[0])
    qc.cx(q3[1],q3[2])
    qc.cx(q3[0],q3[2])
    qc.cx(q1[2],q1[3])
    qc.cx(q1[2],q1[0])
    qc.cx(q2[2],q2[3])
    qc.cx(q2[2],q2[0])

    qc.barrier(q1,q2,q3,q4,q5,q6)
    qc.ccx(q1[0],q2[0],q3[2])
    qc.ccx(q1[1],q2[1],q3[3])
    qc.ccx(q1[2],q2[2],q3[0])
    qc.ccx(q1[3],q2[3],q3[1])
    qc.ccx(q4[0],q4[1],q4[2])
    qc.barrier(q1,q2,q3,q4,q5,q6)

    qc.cx(q1[2],q1[0])
    qc.cx(q1[2],q1[3])
    qc.cx(q2[2],q2[0])
    qc.cx(q2[2],q2[3])
    qc.cx(q3[0],q3[2])
    qc.cx(q3[1],q3[2])
    qc.cx(q3[3],q3[0])
    qc.cx(q3[2],q3[3])
    qc.cx(q3[0],q3[2])

    qc.cx(q4[2],q3[0])

    qc.cx(q1[3],q1[2])
    qc.cx(q1[1],q1[3])
    qc.cx(q1[0],q1[1])
    qc.cx(q1[1],q1[2])
    qc.cx(q2[3],q2[2])
    qc.cx(q2[1],q2[3])
    qc.cx(q2[0],q2[1])
    qc.cx(q2[1],q2[2])
    qc.cx(q3[1],q3[3])
    qc.cx(q3[0],q3[1])
    qc.cx(q3[2],q3[0])

    qc.barrier(q1,q2,q3,q4,q5,q6)
    qc.ccx(q1[0],q2[0],q3[2])
    qc.ccx(q1[1],q2[1],q3[1])
    qc.ccx(q1[2],q2[2],q3[3])
    qc.ccx(q1[3],q2[3],q3[0])
    qc.ccx(q4[0],q4[1],q4[2])
    qc.barrier(q1,q2,q3,q4,q5,q6)
    
    qc.cx(q1[1],q1[2])
    qc.cx(q1[0],q1[1])
    qc.cx(q1[1],q1[3])
    qc.cx(q1[3],q1[2])
    qc.cx(q2[1],q2[2])
    qc.cx(q2[0],q2[1])
    qc.cx(q2[1],q2[3])
    qc.cx(q2[3],q2[2])
    qc.cx(q3[2],q3[0])
    qc.cx(q3[0],q3[1])
    qc.cx(q3[1],q3[3])

    qc.cx(q1[3],q4[0])
    qc.cx(q2[3],q4[1])

# %% [markdown]
# Verification of S-box quantum circuit correctness. Current input: x=11111111={ff}, y=11111111={ff}

# %%
qc=QuantumCircuit(q1,q2,q3,q4,q5,q6,q7,c1,c2,c3,c4,c5,c6,c7)

#16 selectable NOT gates for controlling input
qc.x(q1[0])
qc.x(q1[1])
qc.x(q1[2])
qc.x(q1[3])
qc.x(q2[0])
qc.x(q2[1])
qc.x(q2[2])
qc.x(q2[3])
qc.x(q5[0])
qc.x(q5[1])
qc.x(q5[2])
qc.x(q5[3])
qc.x(q6[0])
qc.x(q6[1])
qc.x(q6[2])
qc.x(q6[3])

#Deploy components according to Figure 9
Phi(q1,q2)
B_Phi_inv_dagger(q5,q6)
theta(q1,q2,q3,q7)
inv_2(q3,q4,q7)
C_mul(q2,q4,q5,q7)
C_mul(q1,q4,q6,q7)
inv_2_dagger(q3,q4,q7)
theta_dagger(q1,q2,q3,q7)
Phi_dagger(q1,q2)
B_Phi_c(q5,q6)


#Perform measurement
qc.barrier(q1,q2,q3,q4,q5,q6,q7)
qc.measure(q1,c1)
qc.measure(q2,c2)
qc.measure(q3,c3)
qc.measure(q4,c4)
qc.measure(q5,c5)
qc.measure(q6,c6)
qc.measure(q7,c7)

qc.draw('mpl',fold=41)

# %% [markdown]
# Measurement results obtained. The measurement results show the auxiliary qubit states in the first 4 bits and bits 13-20, the input state in the last 8 bits, and the output state in bits 5-12.
#
# The current output state is 11101001={e9}, while the output register's initial value was 11111111={ff}. According to the specification, the substitution value for input state {ff} should be {16}=00010110. The observed output 11101001 correctly matches the expected result of 11111111$\oplus$00010110.

# %%
from qiskit_aer import Aer
simulator = Aer.get_backend('aer_simulator')
result = simulator.run(qc, shots=10, memory=True).result()
memory = result.get_memory(qc)
print(memory)
# Out:
# ['0000 1110 1001 0000 0000 1111 1111', '0000 1110 1001 0000 0000 1111 1111', '0000 1110 1001 0000 0000 1111 1111', '0000 1110 1001 0000 0000 1111 1111', '0000 1110 1001 0000 0000 1111 1111', '0000 1110 1001 0000 0000 1111 1111', '0000 1110 1001 0000 0000 1111 1111', '0000 1110 1001 0000 0000 1111 1111', '0000 1110 1001 0000 0000 1111 1111', '0000 1110 1001 0000 0000 1111 1111']

# %% [markdown]
# Quantum gate count statistics (NOT gate count includes those used for S-box input generation):

# %%
print(qc.count_ops())
# Out:
# OrderedDict([('cx', 330), ('ccx', 64), ('swap', 44), ('barrier', 31), ('measure', 28), ('x', 20)])
